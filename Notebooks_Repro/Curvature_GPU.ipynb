# %% [markdown]
# # Adaptive PDE discretizations on cartesian grids
# ## Volume : Reproducible research
# ## Part : Eikonal CPU/GPU solvers comparison
# ## Chapter : Curvature penalized models

# %% [markdown]
# In this notebook, we solve non-holonomic eikonal equations on the CPU and GPU, related to curvature penalized models.
# Our purpose is to establish that the schemes produce consistent results.

# %% [markdown]
# [**Summary**](Summary.ipynb) of volume Reproducible research, this series of notebooks.
#
# [**Main summary**](../Summary.ipynb) of the Adaptive Grid Discretizations
# 	book of notebooks, including the other volumes.
#
# # Table of contents
#   * [1. Constant cost](#1.-Constant-cost)
#     * [1.1 Elastica](#1.1-Elastica)
#     * [1.2 Reeds-Shepp](#1.2-Reeds-Shepp)
#     * [1.3 ReedsShepp forward](#1.3-ReedsShepp-forward)
#     * [1.4 Dubins](#1.4-Dubins)
#
#
#
# **Acknowledgement.** The experiments presented in these notebooks are part of ongoing research,
# some of it with PhD student Guillaume Bonnet, in co-direction with Frederic Bonnans.
#
# Copyright Jean-Marie Mirebeau, University Paris-Sud, CNRS, University Paris-Saclay

# %% [markdown]
# ## 0. Importing the required libraries

# %%
import sys; sys.path.insert(0,"..")
#from Miscellaneous import TocTools; print(TocTools.displayTOC('Curvature_GPU','Repro'))

# %%
from agd import AutomaticDifferentiation as ad
if ad.cupy_generic.cp is None: raise ad.DeliberateNotebookError('Cupy module required')
from agd import Eikonal
from agd import Metrics
from agd import FiniteDifferences as fd
from agd import LinearParallel as lp
import agd.AutomaticDifferentiation.cupy_generic as cugen

norm_infinity = ad.Optimization.norm_infinity
from agd.ExportedCode.Notebooks_Repro.Isotropic_GPU import RunCompare

# %%
import cupy as cp
import numpy as np
import itertools
from matplotlib import pyplot as plt
np.set_printoptions(edgeitems=30, linewidth=100000, formatter=dict(float=lambda x: "%5.3g" % x))

# %%
def ReloadPackages():
    from Miscellaneous.rreload import rreload
    global Eikonal,ad,cugen,RunGPU,RunSmart,Metrics
    Eikonal,ad,cugen,Metrics = rreload([EIkonal,ad,cugen,Metrics],"../..")    
    Eikonal.dictIn.default_mode = 'gpu'

# %%
cp = ad.functional.decorate_module_functions(cp,cugen.set_output_dtype32) # Use float32 and int32 types in place of float64 and int64
plt = ad.functional.decorate_module_functions(plt,cugen.cupy_get_args)
Eikonal.dictIn.default_mode = 'gpu'

# %% [markdown]
# ### 0.1 Additional configuration

# %%
large_instances = False

# %% [markdown]
# ## 1. Constant cost

# %% [markdown]
# ### 1.1 Elastica
# The Euler elastica model is my favorite for the beauty of the curves it creates. However, it is also the hardest to accelerate on the GPU, due to the very wide stencils used.

# %%
n = 300 if large_instances else 100 
nTheta = 96 if large_instances else 64
hfmIn = Eikonal.dictIn({
    'model':'Elastica2',
    'seeds':cp.array([[0.,0.,np.pi]]),
    'exportValues':1,
    'cost':1,
    'xi':0.4,
    'count_updates':True,
#    'solver':'fast_iterative_method','fim_front_width':5,#'traits':{'niter_i':4},
})
hfmIn.SetRect([[-1,1],[-1,1]],dimx=n+1,sampleBoundary=True)
hfmIn.nTheta=nTheta
        
tips = hfmIn.Grid(dims=(4,4,4))
tips = np.moveaxis(tips.reshape(3,-1),0,-1)
hfmIn['tips'] = tips

# %%
#hfmIn.Run();

# %%
gpuOut,cpuOut = RunCompare(hfmIn,check=0.02,check_ratio=0.01)
# Out:
# Setting the kernel traits.
# Preparing the domain data (shape,metric,...)
# Preparing the problem rhs (cost, seeds,...)
# Preparing the GPU kernel
# Running the eikonal GPU kernel
# GPU kernel eikonal ran for 0.35200023651123047 seconds, and 211 iterations.
# Post-Processing
# --- gpu done, turning to cpu ---
# Field verbosity defaults to 1
# Field eps defaults to 0.1
# Field order defaults to 1
# Field seedRadius defaults to 0
# Fast marching solver completed in 4.372 s.
# Field geodesicSolver defaults to Discrete
# Field geodesicStep defaults to 0.25
# Field geodesicWeightThreshold defaults to 0.001
# Field geodesicVolumeBound defaults to 10.985
# Ended Geodesic Discrete Solver
# ***** Warning ! *****
# Unused fields from user: count_updates
# ********************
# Solver time (s). GPU : 0.35200023651123047, CPU : 4.379. Device acceleration : 12.44033255034557
# Max |gpuValues-cpuValues| :  1.5052809972819832

# %%
assert all(stop in ('AtSeed','PastSeed') for stop in gpuOut['geodesic_stopping_criteria'])

# %%
#np.sum(np.abs(gpuOut['values'].get()-cpuOut['values'])>0.02)/gpuOut['values'].size

# %% [markdown]
# The mean number of updates of any block.

# %%
np.mean(gpuOut['stats']['eikonal']['nupdate_o'])
# Out:
# array( 27.1)

# %%
plt.figure(figsize=[15,15])
plt.axis('equal')
for geo in gpuOut['geodesics']: plt.plot(geo[0],geo[1])

# %% [markdown]
# ### 1.2 Reeds-Shepp

# %%
hfmIn['model']='ReedsShepp2'
gpuOut,cpuOut = RunCompare(hfmIn,check=0.002,check_ratio=0.04)
# Out:
# Setting the kernel traits.
# Preparing the domain data (shape,metric,...)
# Preparing the problem rhs (cost, seeds,...)
# Preparing the GPU kernel
# Running the eikonal GPU kernel
# GPU kernel eikonal ran for 0.03697824478149414 seconds, and 39 iterations.
# Post-Processing
# --- gpu done, turning to cpu ---
# Field verbosity defaults to 1
# Field eps defaults to 0.1
# Field projective defaults to 0
# Field order defaults to 1
# Field seedRadius defaults to 0
# Fast marching solver completed in 1.186 s.
# Field geodesicSolver defaults to Discrete
# Field geodesicStep defaults to 0.25
# Field geodesicWeightThreshold defaults to 0.001
# Field geodesicVolumeBound defaults to 10.985
# Ended Geodesic Discrete Solver
# ***** Warning ! *****
# Unused fields from user: count_updates
# ********************
# Solver time (s). GPU : 0.03697824478149414, CPU : 1.192. Device acceleration : 32.2351698152136
# Max |gpuValues-cpuValues| :  0.004388180303490197

# %%
assert all(stop=='AtSeed' for stop in gpuOut['geodesic_stopping_criteria'])

# %% [markdown]
# The number of updates per block

# %%
np.mean(gpuOut['stats']['eikonal']['nupdate_o'])
# Out:
# array( 9.38)

# %%
plt.figure(figsize=[15,15])
plt.axis('equal')
for geo in gpuOut['geodesics']: plt.plot(geo[0],geo[1])

# %% [markdown]
# ### 1.3 ReedsShepp forward

# %%
hfmIn['model']='ReedsSheppForward2'
gpuOut,cpuOut = RunCompare(hfmIn,check=0.005,check_ratio=0.004)
# Out:
# Setting the kernel traits.
# Preparing the domain data (shape,metric,...)
# Preparing the problem rhs (cost, seeds,...)
# Preparing the GPU kernel
# Running the eikonal GPU kernel
# ---------------------------------------------------------------------------
# CUDARuntimeError                          Traceback (most recent call last)
# <ipython-input-18-596917fbb9ca> in <module>
#       1 hfmIn['model']='ReedsSheppForward2'
# ----> 2 gpuOut,cpuOut = RunCompare(hfmIn,check=0.005,check_ratio=0.004)
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\ExportedCode\Notebooks_Repro\Isotropic_GPU.py in RunCompare(gpuIn, check, check_ratio, variants, **kwargs)
#      48     # Run the CPU and GPU solvers
#      49     gpuIn = gpuIn.copy(); gpuIn.update(kwargs)
# ---> 50     gpuOut = gpuIn.Run()
#      51     if gpuIn.get('verbosity',1):  print(f"--- gpu done, turning to cpu ---")
#      52     cpuOut = gpuIn.Run(join={'mode':'cpu_transfer'})
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\DictIn.py in Run(self, join, **kwargs)
#     271
#     272                 from . import HFM_CUDA
# --> 273                 if   self.mode=='gpu': return to_dictOut(HFM_CUDA.RunGPU(self,**kwargs))
#     274                 elif self.mode=='gpu_transfer':
#     275 			gpuStoreIn = ad.cupy_generic.cupy_set(self.store, # host->device
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\__init__.py in RunGPU(hfmIn, cache, *args, **kwargs)
#      24 	"""
#      25         if cache is not None: print(f"Warning : gpu eikonal solver does not support caching")
# ---> 26         return _Interface.Interface(hfmIn).Run(*args,**kwargs)
#      27
#      28         # Arguments for glued domains : glue, far, niter, nitergeo
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_Interface.py in Run(self)
#     125                 self.SetChart()
#     126                 self.SetKernel()
# --> 127                 self.Solve('eikonal')
#     128                 self.PostProcess()
#     129                 self.SolveAD()
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_solvers.py in Solve(self, name)
#      40                 niter_o = adaptive_gauss_siedel_iteration(self,data)
#      41         elif solver == 'fast_iterative_method':
# ---> 42                 niter_o = fast_iterative_method(self,data)
#      43         else: raise ValueError(f"Unrecognized solver : {solver}")
#      44         kernel_time = time.time() - kernel_start # TODO : use cuda event ...
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_solvers.py in fast_iterative_method(self, data)
#     108         # strict_iter_o needed
#     109         for niter_o in range(nitermax_o):
# --> 110                 if stop(updateNext_o): return niter_o
#     111                 updateList_o = cp.ascontiguousarray(cp.flatnonzero(updateNext_o), dtype=self.int_t)
#     112                 scorePrev_o,scoreNext_o = scoreNext_o,scorePrev_o
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_StopCriterion.py in stop(update_o)
#      69
#      70                 # Continue normally if any block is marked for update
# ---> 71                 if np.any(update_o): return False
#      72
#      73                 # Apply boundary conditions if requested
#
# cupy\core\core.pyx in cupy.core.core.ndarray.__nonzero__()
#
# cupy\core\core.pyx in cupy.core.core.ndarray.get()
#
# cupy\core\core.pyx in cupy.core.core.ndarray.get()
#
# cupy\cuda\memory.pyx in cupy.cuda.memory.MemoryPointer.copy_to_host()
#
# cupy\cuda\runtime.pyx in cupy.cuda.runtime.memcpy()
#
# cupy\cuda\runtime.pyx in cupy.cuda.runtime.check_status()
#
# CUDARuntimeError: cudaErrorIllegalAddress: an illegal memory access was encountered

# %%
np.mean(gpuOut['stats']['eikonal']['nupdate_o'])

# %%
# Stationnary deserves investigation...
assert all(stop in ('AtSeed','PastSeed','Stationnary') for stop in gpuOut['geodesic_stopping_criteria'])

# %%
plt.figure(figsize=[15,15])
plt.axis('equal')
for geo in gpuOut['geodesics']: plt.plot(geo[0],geo[1])

# %% [markdown]
# ### 1.4 Dubins

# %%
hfmIn['model']='Dubins2'
gpuOut,cpuOut = RunCompare(hfmIn,check=0.005,check_ratio=0.02) #check=0.005,check_ratio=0.004)
# Out:
# Setting the kernel traits.
# Preparing the domain data (shape,metric,...)
# ---------------------------------------------------------------------------
# CUDARuntimeError                          Traceback (most recent call last)
# <ipython-input-19-45664c9847e7> in <module>
#       1 hfmIn['model']='Dubins2'
# ----> 2 gpuOut,cpuOut = RunCompare(hfmIn,check=0.005,check_ratio=0.02) #check=0.005,check_ratio=0.004)
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\ExportedCode\Notebooks_Repro\Isotropic_GPU.py in RunCompare(gpuIn, check, check_ratio, variants, **kwargs)
#      48     # Run the CPU and GPU solvers
#      49     gpuIn = gpuIn.copy(); gpuIn.update(kwargs)
# ---> 50     gpuOut = gpuIn.Run()
#      51     if gpuIn.get('verbosity',1):  print(f"--- gpu done, turning to cpu ---")
#      52     cpuOut = gpuIn.Run(join={'mode':'cpu_transfer'})
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\DictIn.py in Run(self, join, **kwargs)
#     271
#     272                 from . import HFM_CUDA
# --> 273                 if   self.mode=='gpu': return to_dictOut(HFM_CUDA.RunGPU(self,**kwargs))
#     274                 elif self.mode=='gpu_transfer':
#     275 			gpuStoreIn = ad.cupy_generic.cupy_set(self.store, # host->device
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\__init__.py in RunGPU(hfmIn, cache, *args, **kwargs)
#      24 	"""
#      25         if cache is not None: print(f"Warning : gpu eikonal solver does not support caching")
# ---> 26         return _Interface.Interface(hfmIn).Run(*args,**kwargs)
#      27
#      28         # Arguments for glued domains : glue, far, niter, nitergeo
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_Interface.py in Run(self)
#     121         def Run(self):
#     122                 self.SetKernelTraits()
# --> 123                 self.SetGeometry()
#     124                 self.SetArgs()
#     125                 self.SetChart()
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\HFM_CUDA\_SetGeometry.py in SetGeometry(self)
#      27
#      28         # Domain shape and grid scale
# ---> 29         self.shape = self.hfmIn.shape
#      30
#      31         if self.isCurvature and self.ndim_phys==2: periodic_default = (False,False,True)
#
# ~\Documents\GitHub\AdaptiveGridDiscretizations\agd\Eikonal\DictIn.py in shape(self)
#     288 		"""
#     289                 dims = self['dims']
# --> 290                 if ad.cupy_generic.from_cupy(dims): dims = dims.get()
#     291                 return tuple(dims.astype(int))
#     292
#
# cupy\core\core.pyx in cupy.core.core.ndarray.get()
#
# cupy\core\core.pyx in cupy.core.core.ndarray.get()
#
# cupy\core\core.pyx in cupy.core.core.ndarray.get()
#
# cupy\cuda\memory.pyx in cupy.cuda.memory.MemoryPointer.copy_to_host()
#
# cupy\cuda\runtime.pyx in cupy.cuda.runtime.memcpy()
#
# cupy\cuda\runtime.pyx in cupy.cuda.runtime.check_status()
#
# CUDARuntimeError: cudaErrorIllegalAddress: an illegal memory access was encountered

# %% [markdown]
# Some points of the domain are not reached by the front propagation, due to the non-locally controllable nature of the model.
# No geodesic can be extracted from these points, and the stopping criterion is set to 'InWall'.

# %%
assert all(stop in ('AtSeed','PastSeed','InWall') for stop in gpuOut['geodesic_stopping_criteria'])

# %%
plt.figure(figsize=[15,15])
plt.axis('equal')
for geo in gpuOut['geodesics']: plt.plot(geo[0],geo[1])
