# %%
import numpy as np
import numbers
import cupy as cp

# %%
arr = cp.arange(6)
arr[[1,3,4]]
# Out:
# array([1, 3, 4])

# %%
np.float
# Out:
# float

# %%
h=np.array((1,2,3))
np.broadcast_to(h,(3,5,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-014357317eeb> in <module>
#       1 h=np.array((1,2,3))
# ----> 2 np.broadcast_to(h,(3,5,5))
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# ~/opt/miniconda3/envs/agd-hfm_dev/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     180            [1, 2, 3]])
#     181     """
# --> 182     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     183
#     184
#
# ~/opt/miniconda3/envs/agd-hfm_dev/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     123                          'negative')
#     124     extras = []
# --> 125     it = np.nditer(
#     126         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
# ...

# %%
2**31-1
# Out:
# 2147483647

# %%
issubclass(np.int32,numbers.Integral)
# Out:
# True

# %%
np.dtype('uint8').kind
# Out:
# 'u'
